# %%
#import all the libraries
from selenium import webdriver
import time
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common import keys
import pandas as pd
import os
import openpyxl
from openpyxl import Workbook

#open excel
df = pd.read_excel('Position.xlsx')
book = openpyxl.load_workbook("Position.xlsx")
sheet = book.active

#Open Zerodha Kite
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--incognito")
driver1 = webdriver.Chrome("C:\\Users\\User\\chromedriver.exe",options=chrome_options)
driver1.maximize_window()
driver1.get("https://kite.zerodha.com/")

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--incognito")
driver2 = webdriver.Chrome("C:\\Users\\User\\chromedriver.exe",options=chrome_options)
driver2.maximize_window()
driver2.get("https://kite.zerodha.com/")

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--incognito")
driver3 = webdriver.Chrome("C:\\Users\\User\\chromedriver.exe",options=chrome_options)
driver3.maximize_window()
driver3.get("https://kite.zerodha.com/")

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--incognito")
driver4 = webdriver.Chrome("C:\\Users\\User\\chromedriver.exe",options=chrome_options)
driver4.maximize_window()
driver4.get("https://kite.zerodha.com/")

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--incognito")
driver5 = webdriver.Chrome("C:\\Users\\User\\chromedriver.exe",options=chrome_options)
driver5.maximize_window()
driver5.get("https://kite.zerodha.com/")

client1 = sheet ['A20'].value
client2 = sheet ['A21'].value
client3 = sheet ['A22'].value
client4 = sheet ['A23'].value
client5 = sheet ['A24'].value

pwd1 = sheet ['B20'].value
pwd2 = sheet ['B21'].value
pwd3 = sheet ['B22'].value
pwd4 = sheet ['B23'].value
pwd5 = sheet ['B24'].value

factor = 000000

#opening all the accounts
driver1.find_element_by_xpath("//input[@type='text']").send_keys(client1)
driver1.find_element_by_xpath("//input[@type='password']").send_keys(pwd1)
driver1.find_element_by_xpath("//button[@class='button-orange wide']").click()
time.sleep(2)
driver1.find_element_by_xpath("//input[@type='password']").send_keys(factor)
driver1.find_element_by_xpath("//button[@class='button-orange wide']").click()
driver2.find_element_by_xpath("//input[@type='text']").send_keys(client2)
driver2.find_element_by_xpath("//input[@type='password']").send_keys(pwd2)
driver2.find_element_by_xpath("//button[@class='button-orange wide']").click()
time.sleep(2)
driver2.find_element_by_xpath("//input[@type='password']").send_keys(factor)
driver2.find_element_by_xpath("//button[@class='button-orange wide']").click()
driver3.find_element_by_xpath("//input[@type='text']").send_keys(client3)
driver3.find_element_by_xpath("//input[@type='password']").send_keys(pwd3)
driver3.find_element_by_xpath("//button[@class='button-orange wide']").click()
time.sleep(2)
driver3.find_element_by_xpath("//input[@type='password']").send_keys(factor)
driver3.find_element_by_xpath("//button[@class='button-orange wide']").click()
driver4.find_element_by_xpath("//input[@type='text']").send_keys(client4)
driver4.find_element_by_xpath("//input[@type='password']").send_keys(pwd4)
driver4.find_element_by_xpath("//button[@class='button-orange wide']").click()
time.sleep(2)
driver4.find_element_by_xpath("//input[@type='password']").send_keys(factor)
driver4.find_element_by_xpath("//button[@class='button-orange wide']").click()
driver5.find_element_by_xpath("//input[@type='text']").send_keys(client5)
driver5.find_element_by_xpath("//input[@type='password']").send_keys(pwd5)
driver5.find_element_by_xpath("//button[@class='button-orange wide']").click()
time.sleep(2)
driver5.find_element_by_xpath("//input[@type='password']").send_keys(factor)
driver5.find_element_by_xpath("//button[@class='button-orange wide']").click()

#ORDERS
x = 1
while x <= 50:
    while True:
        call = input("Please Enter  call Here : " )
        print(call)
        

        driver1.find_element_by_xpath("//input[@type='text']").send_keys(call)
        driver1.find_element_by_xpath("//input[@type='text']").send_keys(u'\ue007')
        
        driver2.find_element_by_xpath("//input[@type='text']").send_keys(call)
        driver2.find_element_by_xpath("//input[@type='text']").send_keys(u'\ue007')
        
        driver3.find_element_by_xpath("//input[@type='text']").send_keys(call)
        driver3.find_element_by_xpath("//input[@type='text']").send_keys(u'\ue007')
        
        driver4.find_element_by_xpath("//input[@type='text']").send_keys(call)
        driver4.find_element_by_xpath("//input[@type='text']").send_keys(u'\ue007')
        
        driver5.find_element_by_xpath("//input[@type='text']").send_keys(call)
        driver5.find_element_by_xpath("//input[@type='text']").send_keys(u'\ue007')
        
        driver6.find_element_by_xpath("//input[@type='text']").send_keys(call)
        driver6.find_element_by_xpath("//input[@type='text']").send_keys(u'\ue007')
        
        df = pd.read_excel('Position.xlsx')
        book = openpyxl.load_workbook("Position.xlsx")
        sheet = book.active
        
        quantity1 = sheet ['O2'].value
        quantity2 = sheet ['O3'].value
        quantity3 = sheet ['O4'].value
        quantity4 = sheet ['O5'].value
        quantity5 = sheet ['O6'].value
        quantity6 = sheet ['O7'].value

        
        Entry_Price = sheet ['E2'].value
        SL = sheet ['F2'].value
        SLB = input("ENTER SL %" )
        
        
        print(quantity1)
        print(quantity2)
        print(quantity3)
        print(quantity4)
        print(quantity5)
        print(quantity6)
        print(Entry_Price)
        print(SL)

        B_or_S = input("Enter ENTRY : ")

        if B_or_S == "BI":
            
            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity1)
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(Entry_Price).perform()
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(SL).perform()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity2)
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(Entry_Price).perform()
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(SL).perform()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()




            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity3)
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(Entry_Price).perform()
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(SL).perform()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity4)
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(Entry_Price).perform()
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(SL).perform()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
 
            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity5)
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(Entry_Price).perform()
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(SL).perform()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
            
        if B_or_S == "SI":

            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity1)
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(Entry_Price).perform()
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(SL).perform()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity2)
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(Entry_Price).perform()
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(SL).perform()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()



            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity3)
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(Entry_Price).perform()
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(SL).perform()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity4)
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(Entry_Price).perform()
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(SL).perform()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
 
            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity5)
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(Entry_Price).perform()
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(SL).perform()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
            
            if B_or_S == "BLM":
            
            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity1)
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(Entry_Price).perform()
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(Entry_Price).perform()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]").click()

    
            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity2)
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(Entry_Price).perform()
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(Entry_Price).perform()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]").click()

            
            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity3)
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(Entry_Price).perform()
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(Entry_Price).perform()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]").click()

            
            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity4)
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(Entry_Price).perform()
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(Entry_Price).perform()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]").click()

            
            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity5)
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(Entry_Price).perform()
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(Entry_Price).perform()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]").click()
            
        if B_or_S == "SLM":

            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity1)
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(Entry_Price).perform()
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(Entry_Price).perform()
            driver1.find_element_by_xpath("//body[1]/div[1]/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            
            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity2)
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(Entry_Price).perform()
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(Entry_Price).perform()
            driver2.find_element_by_xpath("//body[1]/div[1]/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
            
            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity3)
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(Entry_Price).perform()
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(Entry_Price).perform()
            driver3.find_element_by_xpath("//body[1]/div[1]/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
            
            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity4)
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(Entry_Price).perform()
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(Entry_Price).perform()
            driver4.find_element_by_xpath("//body[1]/div[1]/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
            
            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity5)
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(Entry_Price).perform()
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(Entry_Price).perform()
            driver5.find_element_by_xpath("//body[1]/div[1]/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click(
            
        if B_or_S == "B":
            
            
            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[1]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[2]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity1)
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(Entry_Price).perform()
            driver1.find_element_by_xpath("//body//div[@id='app']//div//div//div//div[2]//div[1]//div[2]//label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            ActionChains(driver1).send_keys(u'\ue004').perform()
            driver1.find_element_by_xpath("//div[@class='su-input-group']//input").send_keys(SLB)
            driver1.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click()

            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[1]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[2]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity2)
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(Entry_Price).perform()
            driver2.find_element_by_xpath("//body//div[@id='app']//div//div//div//div[2]//div[1]//div[2]//label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            ActionChains(driver2).send_keys(u'\ue004').perform()
            driver2.find_element_by_xpath("//div[@class='su-input-group']//input").send_keys(SLB)
            driver2.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click()


            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[1]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[2]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity3)
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(Entry_Price).perform()
            driver3.find_element_by_xpath("//body//div[@id='app']//div//div//div//div[2]//div[1]//div[2]//label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            ActionChains(driver3).send_keys(u'\ue004').perform()
            driver3.find_element_by_xpath("//div[@class='su-input-group']//input").send_keys(SLB)
            driver3.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click()
            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[1]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[2]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity4)
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(Entry_Price).perform()
            driver4.find_element_by_xpath("//body//div[@id='app']//div//div//div//div[2]//div[1]//div[2]//label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            ActionChains(driver4).send_keys(u'\ue004').perform()
            driver4.find_element_by_xpath("//div[@class='su-input-group']//input").send_keys(SLB)
            driver4.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click()


            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[1]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[2]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity5)
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(Entry_Price).perform()
            driver5.find_element_by_xpath("//body//div[@id='app']//div//div//div//div[2]//div[1]//div[2]//label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            ActionChains(driver5).send_keys(u'\ue004').perform()
            driver5.find_element_by_xpath("//div[@class='su-input-group']//input").send_keys(SLB)
            driver5.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click(

        if B_or_S == "S":
           
            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver1).send_keys(u'\ue003').perform()
            ActionChains(driver1).send_keys(u'\ue003').perform()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity1)
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver2).send_keys(u'\ue003').perform()
            ActionChains(driver2).send_keys(u'\ue003').perform()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity2)
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver3).send_keys(u'\ue003').perform()
            ActionChains(driver3).send_keys(u'\ue003').perform()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity3)
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver4).send_keys(u'\ue003').perform()
            ActionChains(driver4).send_keys(u'\ue003').perform()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity4)
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver5).send_keys(u'\ue003').perform()
            ActionChains(driver5).send_keys(u'\ue003').perform()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity5)
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
            
            driver6.find_element_by_tag_name('body')
            ActionChains(driver6).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver6).send_keys(u'\ue003').perform()
            ActionChains(driver6).send_keys(u'\ue003').perform()
            driver6.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity6)
            driver6.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]").click()
            driver6.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
       
        B_or_S = input("Enter EXIT : ")
        if B_or_S == "B":
           
            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            driver1.find_element_by_xpath("//div[@class='su-input-group su-static-label']//input").send_keys(quantity1)
            driver1.find_element_by_xpath("//label[contains(text(),'MARKET')]").click()
            driver1.find_element_by_xpath("//span[contains(text(),'Buy')]").click()

            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            driver2.find_element_by_xpath("//div[@class='su-input-group su-static-label']//input").send_keys(quantity2)
            driver2.find_element_by_xpath("//label[contains(text(),'MARKET')]").click()
            driver2.find_element_by_xpath("//span[contains(text(),'Buy')]").click()
            
            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            driver3.find_element_by_xpath("//div[@class='su-input-group su-static-label']//input").send_keys(quantity3)
            driver3.find_element_by_xpath("//label[contains(text(),'MARKET')]").click()
            driver3.find_element_by_xpath("//span[contains(text(),'Buy')]").click()
            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            driver4.find_element_by_xpath("//div[@class='su-input-group su-static-label']//input").send_keys(quantity4)
            driver4.find_element_by_xpath("//label[contains(text(),'MARKET')]").click()
            driver4.find_element_by_xpath("//span[contains(text(),'Buy')]").click()
            
            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            driver5.find_element_by_xpath("//div[@class='su-input-group su-static-label']//input").send_keys(quantity5)
            driver5.find_element_by_xpath("//label[contains(text(),'MARKET')]").click()
            driver5.find_element_by_xpath("//span[contains(text(),'Buy')]").click()




       
        if B_or_S == "S":
           
            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver1).send_keys(u'\ue003').perform()
            ActionChains(driver1).send_keys(u'\ue003').perform()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[2]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity1)
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver2).send_keys(u'\ue003').perform()
            ActionChains(driver2).send_keys(u'\ue003').perform()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[2]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity1)
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver3).send_keys(u'\ue003').perform()
            ActionChains(driver3).send_keys(u'\ue003').perform()
            driver3.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity3)
            driver3.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            driver3.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click()
            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver4).send_keys(u'\ue003').perform()
            ActionChains(driver4).send_keys(u'\ue003').perform()
            driver4.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity4)
            driver4.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            driver4.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click()
            
            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver5).send_keys(u'\ue003').perform()
            ActionChains(driver5).send_keys(u'\ue003').perform()
            driver5.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity5)
            driver5.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            driver5.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click()

            print(x)
            x += 1
            
        #DELETING THE CALLS   
        Delete = input("Delete the call : ")
        if Delete == "D":
          
            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(u'\ue017').perform()

            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(u'\ue017').perform()
            
            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(u'\ue017').perform()
            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(u'\ue017').perform()
            
            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(u'\ue017').perform()
            
            driver6.find_element_by_tag_name('body')
            ActionChains(driver6).send_keys(u'\ue017').perform()
                
print("Cannot execute call further")

# %%
#ORDERS
x = 1
while x <= 50:
    while True:
        call = input("Please Enter  call Here : " )
        print(call)
        

        driver1.find_element_by_xpath("//input[@type='text']").send_keys(call)
        driver1.find_element_by_xpath("//input[@type='text']").send_keys(u'\ue007')
        
        driver2.find_element_by_xpath("//input[@type='text']").send_keys(call)
        driver2.find_element_by_xpath("//input[@type='text']").send_keys(u'\ue007')
        
        driver3.find_element_by_xpath("//input[@type='text']").send_keys(call)
        driver3.find_element_by_xpath("//input[@type='text']").send_keys(u'\ue007')
        
        driver4.find_element_by_xpath("//input[@type='text']").send_keys(call)
        driver4.find_element_by_xpath("//input[@type='text']").send_keys(u'\ue007')
        
        driver5.find_element_by_xpath("//input[@type='text']").send_keys(call)
        driver5.find_element_by_xpath("//input[@type='text']").send_keys(u'\ue007')
        
        driver6.find_element_by_xpath("//input[@type='text']").send_keys(call)
        driver6.find_element_by_xpath("//input[@type='text']").send_keys(u'\ue007')
        
        df = pd.read_excel('Position.xlsx')
        book = openpyxl.load_workbook("Position.xlsx")
        sheet = book.active
        
        quantity1 = sheet ['O2'].value
        quantity2 = sheet ['O3'].value
        quantity3 = sheet ['O4'].value
        quantity4 = sheet ['O5'].value
        quantity5 = sheet ['O6'].value
        quantity6 = sheet ['O7'].value

        
        Entry_Price = sheet ['E2'].value
        SL = sheet ['F2'].value
        SLB = input("ENTER SL %" )
        
        
        print(quantity1)
        print(quantity2)
        print(quantity3)
        print(quantity4)
        print(quantity5)
        print(quantity6)
        print(Entry_Price)
        print(SL)

        B_or_S = input("Enter ENTRY : ")

        if B_or_S == "BI":
            
            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity1)
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(Entry_Price).perform()
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(SL).perform()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity2)
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(Entry_Price).perform()
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(SL).perform()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()




            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity3)
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(Entry_Price).perform()
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(SL).perform()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity4)
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(Entry_Price).perform()
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(SL).perform()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
 
            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity5)
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(Entry_Price).perform()
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(SL).perform()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
            
        if B_or_S == "SI":

            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity1)
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(Entry_Price).perform()
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(SL).perform()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity2)
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(Entry_Price).perform()
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(SL).perform()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()



            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity3)
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(Entry_Price).perform()
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(SL).perform()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity4)
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(Entry_Price).perform()
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(SL).perform()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
 
            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[2]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity5)
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(Entry_Price).perform()
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(SL).perform()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
            
            if B_or_S == "BLM":
            
            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity1)
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(Entry_Price).perform()
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(Entry_Price).perform()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]").click()

    
            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity2)
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(Entry_Price).perform()
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(Entry_Price).perform()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]").click()

            
            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity3)
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(Entry_Price).perform()
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(Entry_Price).perform()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]").click()

            
            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity4)
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(Entry_Price).perform()
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(Entry_Price).perform()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]").click()

            
            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity5)
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(Entry_Price).perform()
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(Entry_Price).perform()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]").click()
            
        if B_or_S == "SLM":

            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity1)
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(Entry_Price).perform()
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(Entry_Price).perform()
            driver1.find_element_by_xpath("//body[1]/div[1]/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            
            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity2)
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(Entry_Price).perform()
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(Entry_Price).perform()
            driver2.find_element_by_xpath("//body[1]/div[1]/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
            
            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity3)
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(Entry_Price).perform()
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(Entry_Price).perform()
            driver3.find_element_by_xpath("//body[1]/div[1]/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
            
            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity4)
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(Entry_Price).perform()
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(Entry_Price).perform()
            driver4.find_element_by_xpath("//body[1]/div[1]/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
            
            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[1]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[3]/div[1]/div[1]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity5)
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(Entry_Price).perform()
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(Entry_Price).perform()
            driver5.find_element_by_xpath("//body[1]/div[1]/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click(
            
        if B_or_S == "B":
            
            
            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[1]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[2]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity1)
            ActionChains(driver1).send_keys(u'\ue004').perform()
            ActionChains(driver1).send_keys(Entry_Price).perform()
            driver1.find_element_by_xpath("//body//div[@id='app']//div//div//div//div[2]//div[1]//div[2]//label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            ActionChains(driver1).send_keys(u'\ue004').perform()
            driver1.find_element_by_xpath("//div[@class='su-input-group']//input").send_keys(SLB)
            driver1.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click()

            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[1]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[2]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity2)
            ActionChains(driver2).send_keys(u'\ue004').perform()
            ActionChains(driver2).send_keys(Entry_Price).perform()
            driver2.find_element_by_xpath("//body//div[@id='app']//div//div//div//div[2]//div[1]//div[2]//label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            ActionChains(driver2).send_keys(u'\ue004').perform()
            driver2.find_element_by_xpath("//div[@class='su-input-group']//input").send_keys(SLB)
            driver2.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click()


            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[1]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[2]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity3)
            ActionChains(driver3).send_keys(u'\ue004').perform()
            ActionChains(driver3).send_keys(Entry_Price).perform()
            driver3.find_element_by_xpath("//body//div[@id='app']//div//div//div//div[2]//div[1]//div[2]//label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            ActionChains(driver3).send_keys(u'\ue004').perform()
            driver3.find_element_by_xpath("//div[@class='su-input-group']//input").send_keys(SLB)
            driver3.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click()
            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[1]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[2]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity4)
            ActionChains(driver4).send_keys(u'\ue004').perform()
            ActionChains(driver4).send_keys(Entry_Price).perform()
            driver4.find_element_by_xpath("//body//div[@id='app']//div//div//div//div[2]//div[1]//div[2]//label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            ActionChains(driver4).send_keys(u'\ue004').perform()
            driver4.find_element_by_xpath("//div[@class='su-input-group']//input").send_keys(SLB)
            driver4.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click()


            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[1]/div[1]/div[1]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[2]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity5)
            ActionChains(driver5).send_keys(u'\ue004').perform()
            ActionChains(driver5).send_keys(Entry_Price).perform()
            driver5.find_element_by_xpath("//body//div[@id='app']//div//div//div//div[2]//div[1]//div[2]//label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            ActionChains(driver5).send_keys(u'\ue004').perform()
            driver5.find_element_by_xpath("//div[@class='su-input-group']//input").send_keys(SLB)
            driver5.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click(

        if B_or_S == "S":
           
            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver1).send_keys(u'\ue003').perform()
            ActionChains(driver1).send_keys(u'\ue003').perform()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity1)
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver2).send_keys(u'\ue003').perform()
            ActionChains(driver2).send_keys(u'\ue003').perform()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity2)
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver3).send_keys(u'\ue003').perform()
            ActionChains(driver3).send_keys(u'\ue003').perform()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity3)
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]").click()
            driver3.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver4).send_keys(u'\ue003').perform()
            ActionChains(driver4).send_keys(u'\ue003').perform()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity4)
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]").click()
            driver4.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver5).send_keys(u'\ue003').perform()
            ActionChains(driver5).send_keys(u'\ue003').perform()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity5)
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]").click()
            driver5.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
            
            driver6.find_element_by_tag_name('body')
            ActionChains(driver6).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver6).send_keys(u'\ue003').perform()
            ActionChains(driver6).send_keys(u'\ue003').perform()
            driver6.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity6)
            driver6.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]").click()
            driver6.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()
       
        B_or_S = input("Enter EXIT : ")
        if B_or_S == "B":
           
            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            driver1.find_element_by_xpath("//div[@class='su-input-group su-static-label']//input").send_keys(quantity1)
            driver1.find_element_by_xpath("//label[contains(text(),'MARKET')]").click()
            driver1.find_element_by_xpath("//span[contains(text(),'Buy')]").click()

            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            driver2.find_element_by_xpath("//div[@class='su-input-group su-static-label']//input").send_keys(quantity2)
            driver2.find_element_by_xpath("//label[contains(text(),'MARKET')]").click()
            driver2.find_element_by_xpath("//span[contains(text(),'Buy')]").click()
            
            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            driver3.find_element_by_xpath("//div[@class='su-input-group su-static-label']//input").send_keys(quantity3)
            driver3.find_element_by_xpath("//label[contains(text(),'MARKET')]").click()
            driver3.find_element_by_xpath("//span[contains(text(),'Buy')]").click()
            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            driver4.find_element_by_xpath("//div[@class='su-input-group su-static-label']//input").send_keys(quantity4)
            driver4.find_element_by_xpath("//label[contains(text(),'MARKET')]").click()
            driver4.find_element_by_xpath("//span[contains(text(),'Buy')]").click()
            
            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            driver5.find_element_by_xpath("//div[@class='su-input-group su-static-label']//input").send_keys(quantity5)
            driver5.find_element_by_xpath("//label[contains(text(),'MARKET')]").click()
            driver5.find_element_by_xpath("//span[contains(text(),'Buy')]").click()




       
        if B_or_S == "S":
           
            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver1).send_keys(u'\ue003').perform()
            ActionChains(driver1).send_keys(u'\ue003').perform()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[2]/label[1]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity1)
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]]").click()
            driver1.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver2).send_keys(u'\ue003').perform()
            ActionChains(driver2).send_keys(u'\ue003').perform()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[1]/div[1]/div[2]/label[1]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[1]/div[1]/div[1]/input[1]").send_keys(quantity1)
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/label[1]]").click()
            driver2.find_element_by_xpath("//body/div[@id='app']/form[1]/section[1]/footer[1]/div[1]/div[2]/button[1]/span[1]").click()

            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver3).send_keys(u'\ue003').perform()
            ActionChains(driver3).send_keys(u'\ue003').perform()
            driver3.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity3)
            driver3.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            driver3.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click()
            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver4).send_keys(u'\ue003').perform()
            ActionChains(driver4).send_keys(u'\ue003').perform()
            driver4.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity4)
            driver4.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            driver4.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click()
            
            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(B_or_S).perform()
            time.sleep(2)
            ActionChains(driver5).send_keys(u'\ue003').perform()
            ActionChains(driver5).send_keys(u'\ue003').perform()
            driver5.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div/div[1]/div[1]/input[1]").send_keys(quantity5)
            driver5.find_element_by_xpath("//body/div[@id='app']/form/section/div/div/div[2]/div[1]/label[1]/span[1]").click()
            driver5.find_element_by_xpath("//div[@id='app']//form//section//footer//div//div//button//span").click()

            print(x)
            x += 1
            
        #DELETING THE CALLS   
        Delete = input("Delete the call : ")
        if Delete == "D":
          
            driver1.find_element_by_tag_name('body')
            ActionChains(driver1).send_keys(u'\ue017').perform()

            driver2.find_element_by_tag_name('body')
            ActionChains(driver2).send_keys(u'\ue017').perform()
            
            driver3.find_element_by_tag_name('body')
            ActionChains(driver3).send_keys(u'\ue017').perform()
            
            driver4.find_element_by_tag_name('body')
            ActionChains(driver4).send_keys(u'\ue017').perform()
            
            driver5.find_element_by_tag_name('body')
            ActionChains(driver5).send_keys(u'\ue017').perform()
            
            driver6.find_element_by_tag_name('body')
            ActionChains(driver6).send_keys(u'\ue017').perform()
                
print("Cannot execute call further")
# Out:
# Please Enter  call Here : HDFC BAnk
# HDFC BAnk
# ENTER SL %0
# 225
# 125
# 125
# 125
# 125
# 125
# None
# None
